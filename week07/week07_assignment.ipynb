# %% [markdown]
# # Week 7 Assignment
#
# This week has been all about getting information off the internet both in structured data formats (CSV, JSON, etc) as well as HTML.  Answer the questions below as instructed.

# %% [markdown]
# ### 31.1 Finding files on the internet
#
# Go to healthdata.gov and find a file that looks interesting to you.  Provide the metadata below that describes the file you located.
#
# The cell below is a "markdown" cell.  Just double-click it to edit the contents and then Shift-Enter to show the content as formatted text.
#
# ---

# %% [markdown]
# **File Name:**  cscpopendata.csv
#
# **URL to Page:** https://healthdata.gov/dataset/chemicals-cosmetics
#
# **Description:** This article focuses on collecting information about possibly hazardous ingredients present in makeup in California and making it availible to the public. I obviously don't live in California, but I still find it interesting to see what harmful things could be in products that people are using everyday.
#
# **URL to Actual File:** https://healthdata.gov/node/3162801/download
#
# **File Format:** CSV

# %% [markdown]
# ---

# %% [markdown]
# ### 31.2 Use Pandas to load data from internet
#
# Now write a block of code (doesn't need to be in a function) that will load the file using Pandas and describe the shape of the file contents.  I've provided a cell with some comments in it to help get you started.
#
# Pandas documentation for loading data https://pandas.pydata.org/pandas-docs/version/0.23.4/api.html#input-output
#
# Pandas documentation for describing the shape of data https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.shape.html

# %%
import pandas as pd

# Load data using one of the read functions depending on your data file type
# data = pd.read_ ...
url = "https://healthdata.gov/node/3162801/download"
data = pd.read_csv(url)

df = pd.DataFrame(data)

# Print out the row / column count
# data. ...
print("The row and column count of this data set is" + str(df.shape))

data
# Out:
# The row and column count of this data set is(113179, 22)
#         CDPHId                                       ProductName    CSFId  \
# 0            2  ULTRA COLOR RICH EXTRA PLUMP LIPSTICK-ALL SHADES      NaN
# 1            3                        Glover's Medicated Shampoo      NaN
# 2            3                        Glover's Medicated Shampoo      NaN
# 3            4          PRECISION GLIMMER EYE LINER-ALL SHADES �      NaN
# 4            5       AVON BRILLIANT SHINE LIP GLOSS-ALL SHADES �      NaN
# ...        ...                                               ...      ...
# 113174   41183              be you. naturally. eyeshadow palette  64368.0
# 113175   41183              be you. naturally. eyeshadow palette  64369.0
# 113176   41183              be you. naturally. eyeshadow palette  64370.0
# 113177   41183              be you. naturally. eyeshadow palette  64371.0
# 113178   41183              be you. naturally. eyeshadow palette  64372.0
#
#                  CSF  CompanyId          CompanyName BrandName  \
# 0                NaN          4         New Avon LLC      AVON
# 1                NaN        338  J. Strickland & Co.  Glover's
# 2                NaN        338  J. Strickland & Co.  Glover's
# 3                NaN          4         New Avon LLC      AVON
# 4                NaN          4         New Avon LLC      AVON
# ...              ...        ...                  ...       ...
# 113174      daybreak        224      Tarte Cosmetics     tarte
# 113175       sunbeam        224      Tarte Cosmetics     tarte
# 113176        earthy        224      Tarte Cosmetics     tarte
# 113177      tropical        224      Tarte Cosmetics     tarte
# 113178  crystallized        224      Tarte Cosmetics     tarte
#
#         PrimaryCategoryId                    PrimaryCategory  SubCategoryId  \
# 0                      44    Makeup Products (non-permanent)             53
# 1                      18  Hair Care Products (non-coloring)             25
# 2                      18  Hair Care Products (non-coloring)             25
# 3                      44    Makeup Products (non-permanent)             46
# 4                      44    Makeup Products (non-permanent)             52
# ...                   ...                                ...            ...
# 113174                 44    Makeup Products (non-permanent)             48
# 113175                 44    Makeup Products (non-permanent)             48
# 113176                 44    Makeup Products (non-permanent)             48
# 113177                 44    Makeup Products (non-permanent)             48
# 113178                 44    Makeup Products (non-permanent)             48
#
#         ...   CasNumber  ChemicalId            ChemicalName  \
# 0       ...  13463-67-7           6        Titanium dioxide
# 1       ...  65996-92-1           4  Distillates (coal tar)
# 2       ...    140-67-0           5               Estragole
# 3       ...  13463-67-7           7        Titanium dioxide
# 4       ...  13463-67-7           8        Titanium dioxide
# ...     ...         ...         ...                     ...
# 113174  ...  13463-67-7       67472        Titanium dioxide
# 113175  ...  13463-67-7       67472        Titanium dioxide
# 113176  ...  13463-67-7       67472        Titanium dioxide
# 113177  ...  13463-67-7       67472        Titanium dioxide
# 113178  ...  13463-67-7       67472        Titanium dioxide
#
#         InitialDateReported MostRecentDateReported DiscontinuedDate  \
# 0                06/17/2009             08/28/2013       02/01/2011
# 1                07/01/2009             07/01/2009              NaN
# 2                07/01/2009             07/01/2009              NaN
# 3                07/09/2009             08/28/2013              NaN
# 4                07/09/2009             08/28/2013       02/01/2011
# ...                     ...                    ...              ...
# 113174           02/26/2020             02/26/2020              NaN
# 113175           02/26/2020             02/26/2020              NaN
# 113176           02/26/2020             02/26/2020              NaN
# 113177           02/26/2020             02/26/2020              NaN
# 113178           02/26/2020             02/26/2020              NaN
#
#        ChemicalCreatedAt ChemicalUpdatedAt ChemicalDateRemoved ChemicalCount
# 0             07/09/2009        07/09/2009                 NaN             1
# 1             07/01/2009        07/01/2009                 NaN             2
# 2             07/02/2009        07/02/2009                 NaN             2
# 3             07/09/2009        07/09/2009                 NaN             1
# 4             07/09/2009        07/09/2009                 NaN             1
# ...                  ...               ...                 ...           ...
# 113174        02/26/2020        02/26/2020                 NaN             1
# 113175        02/26/2020        02/26/2020                 NaN             1
# 113176        02/26/2020        02/26/2020                 NaN             1
# 113177        02/26/2020        02/26/2020                 NaN             1
# 113178        02/26/2020        02/26/2020                 NaN             1
#
# [113179 rows x 22 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### 32.1 HTML Basics
#
# HTML is a form of which othere data format we've talked about:
#
# > A) Binary
# >
# > B) eXtensible Markup Language
# >
# > C) JavaScript Object Notation
# >
# > D) HL7 FHIR

# %%
answer321 = "B"

# %% [markdown]
# ### 32.2 Things in HTML
#
# Which of the following is **not** a part of HTML:
#
# > A) element
# >
# > B) tag
# >
# > C) dictionary
# >
# > D) attribute

# %%
answer322 = "C"

# %% [markdown]
# ### 32.3 Parsing HTML in Python
#
# Which of the following packages can be used to extract a table of data from HTML using Python (include all that apply in a list):
#
# > A) lxml
# >
# > B) BeautifulSoup
# >
# > C) Pandas
# >
# > D) fuzzywuzzy

# %%
answer323 = ["A","B"]
